# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout, Input, Add, Dense, Activation, BatchNormalization, Flatten, Conv2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix
import itertools
# Out:
# WARNING:tensorflow:From C:\Users\THUNDER REDDY\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Define the custom function for plotting confusion matrices
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Define paths and filenames
path = Path(r"C:\Users\THUNDER REDDY\OneDrive\Downloads\UTKFace")
filenames = list(map(lambda x: x.name, path.glob('*.jpg')))

# Shuffle filenames
np.random.seed(10)
np.random.shuffle(filenames)

# %%
# Extract age and gender labels from filenames
age_labels, gender_labels, image_path = [], [], []

for filename in filenames:
    image_path.append(filename)
    temp = filename.split('_')
    age_labels.append(temp[0])
    gender_labels.append(temp[1])

# %%
# Create DataFrame
df = pd.DataFrame()
df['image'], df['age'], df['gender'] = image_path, age_labels, gender_labels

# Convert data types
gender_dict = {0:"Male", 1:"Female"}
df = df.astype({'age': 'float32', 'gender': 'int32'})

# %%
# Load and display an example image
img = Image.open(path / df.image[160])
plt.imshow(img)

# %%
# Plot distributional graph for age
sns.distplot(df.age)
# Out:
# C:\Users\THUNDER REDDY\AppData\Local\Temp\ipykernel_12052\2886575943.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.age)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Density'>

# %%
# Display some example images with age and gender labels
files = df.iloc[0:20]
plt.figure(figsize=(15, 15))
for index, file, age, gender in files.itertuples():
    plt.subplot(5, 5, index+1)
    img = load_img(path / file)
    img = np.array(img)
    plt.imshow(img)
    plt.title(f"Age: {age} Gender: {gender_dict[gender]}")
    plt.axis('off')

# %%
# Train-test split
train, test = train_test_split(df, test_size=0.80, random_state=42)

# %%
# Prepare training data
x_train = []
for file in train.image:
    img = load_img(path / file, color_mode='grayscale')
    img = img.resize((128, 128))
    img = np.array(img)
    x_train.append(img)

x_train = np.array(x_train) 
x_train = x_train.reshape(len(x_train), 128, 128, 1)
x_train = x_train / 255

# Prepare labels
y_gender = np.array(train.gender)
y_age = np.array(train.age)

# %%
# Define model architecture
input_shape = (128, 128, 1)
inputs = Input(shape=input_shape)
X = Conv2D(64, (3, 3), activation='relu')(inputs)
X = MaxPooling2D((2, 2))(X)
X = Conv2D(128, (3, 3), activation='relu')(X)
X = MaxPooling2D((2, 2))(X)
X = Conv2D(256, (3, 3), activation='relu')(X)
X = MaxPooling2D((2, 2))(X)
X = Flatten()(X)
X = Dense(512, activation='relu')(X)
X = Dropout(0.5)(X)

# Output layers
output_gender = Dense(1, activation='sigmoid', name='gender_output')(X)
output_age = Dense(1, activation='linear', name='age_output')(X)
# Out:
# WARNING:tensorflow:From C:\Users\THUNDER REDDY\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\THUNDER REDDY\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# Compile the model
model = Model(inputs=inputs, outputs=[output_gender, output_age])
model.compile(loss=['binary_crossentropy', 'mae'], optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\THUNDER REDDY\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
model_history = model.fit(x_train, [y_gender, y_age], batch_size=32, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\THUNDER REDDY\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\THUNDER REDDY\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 134/134 [==============================] - 116s 824ms/step - loss: 17.6360 - gender_output_loss: 1.0020 - age_output_loss: 16.6339 - gender_output_accuracy: 0.5122 - age_output_accuracy: 0.0488 - val_loss: 16.4906 - val_gender_output_loss: 0.6422 - val_age_output_loss: 15.8484 - val_gender_output_accuracy: 0.6253 - val_age_output_accuracy: 0.0632
# Epoch 2/50
# 134/134 [==============================] - 110s 823ms/step - loss: 15.2167 - gender_output_loss: 0.7234 - age_output_loss: 14.4933 - gender_output_accuracy: 0.6395 - age_output_accuracy: 0.0488 - val_loss: 13.3365 - val_gender_output_loss: 0.5809 - val_age_output_loss: 12.7556 - val_gender_output_accuracy: 0.6716 - val_age_output_accuracy: 0.0632
# Epoch 3/50
# 134/134 [==============================] - 109s 813ms/step - loss: 13.0684 - gender_output_loss: 0.5778 - age_output_loss: 12.4905 - gender_output_accuracy: 0.7138 - age_output_accuracy: 0.0452 - val_loss: 11.9430 - val_gender_output_loss: 0.5083 - val_age_output_loss: 11.4347 - val_gender_output_accuracy: 0.7389 - val_age_output_accuracy: 0.0611
# Epoch 4/50
# 134/134 [==============================] - 110s 821ms/step - loss: 12.0996 - gender_output_loss: 0.5294 - age_output_loss: 11.5702 - gender_output_accuracy: 0.7485 - age_output_accuracy: 0.0394 - val_loss: 11.9110 - val_gender_output_loss: 0.4587 - val_age_output_loss: 11.4523 - val_gender_output_accuracy: 0.7895 - val_age_output_accuracy: 0.0358
# Epoch 5/50
# 134/134 [==============================] - 111s 830ms/step - loss: 11.2098 - gender_output_loss: 0.4857 - age_output_loss: 10.7241 - gender_output_accuracy: 0.7733 - age_output_accuracy: 0.0375 - val_loss: 10.6865 - val_gender_output_loss: 0.4269 - val_age_output_loss: 10.2596 - val_gender_output_accuracy: 0.7832 - val_age_output_accuracy: 0.0463
# Epoch 6/50
# 134/134 [==============================] - 109s 813ms/step - loss: 10.5639 - gender_output_loss: 0.4733 - age_output_loss: 10.0906 - gender_output_accuracy: 0.7792 - age_output_accuracy: 0.0352 - val_loss: 10.0471 - val_gender_output_loss: 0.3812 - val_age_output_loss: 9.6659 - val_gender_output_accuracy: 0.8232 - val_age_output_accuracy: 0.0442
# Epoch 7/50
# 134/134 [==============================] - 91s 677ms/step - loss: 10.1492 - gender_output_loss: 0.4345 - age_output_loss: 9.7147 - gender_output_accuracy: 0.7949 - age_output_accuracy: 0.0347 - val_loss: 9.5150 - val_gender_output_loss: 0.4032 - val_age_output_loss: 9.1119 - val_gender_output_accuracy: 0.8105 - val_age_output_accuracy: 0.0337
# Epoch 8/50
# 134/134 [==============================] - 66s 495ms/step - loss: 9.3368 - gender_output_loss: 0.4019 - age_output_loss: 8.9349 - gender_output_accuracy: 0.8146 - age_output_accuracy: 0.0326 - val_loss: 9.3152 - val_gender_output_loss: 0.3941 - val_age_output_loss: 8.9211 - val_gender_output_accuracy: 0.8084 - val_age_output_accuracy: 0.0379
# Epoch 9/50
# 134/134 [==============================] - 67s 498ms/step - loss: 9.3285 - gender_output_loss: 0.3920 - age_output_loss: 8.9365 - gender_output_accuracy: 0.8254 - age_output_accuracy: 0.0328 - val_loss: 9.0270 - val_gender_output_loss: 0.3716 - val_age_output_loss: 8.6553 - val_gender_output_accuracy: 0.8168 - val_age_output_accuracy: 0.0337
# Epoch 10/50
# 134/134 [==============================] - 68s 508ms/step - loss: 8.7556 - gender_output_loss: 0.3745 - age_output_loss: 8.3812 - gender_output_accuracy: 0.8293 - age_output_accuracy: 0.0326 - val_loss: 8.6557 - val_gender_output_loss: 0.3513 - val_age_output_loss: 8.3044 - val_gender_output_accuracy: 0.8253 - val_age_output_accuracy: 0.0379
# Epoch 11/50
# 134/134 [==============================] - 66s 495ms/step - loss: 8.4624 - gender_output_loss: 0.3696 - age_output_loss: 8.0928 - gender_output_accuracy: 0.8286 - age_output_accuracy: 0.0345 - val_loss: 9.4757 - val_gender_output_loss: 0.3683 - val_age_output_loss: 9.1074 - val_gender_output_accuracy: 0.8337 - val_age_output_accuracy: 0.0337
# Epoch 12/50
# 134/134 [==============================] - 394s 3s/step - loss: 7.9030 - gender_output_loss: 0.3408 - age_output_loss: 7.5622 - gender_output_accuracy: 0.8486 - age_output_accuracy: 0.0345 - val_loss: 8.7528 - val_gender_output_loss: 0.3437 - val_age_output_loss: 8.4091 - val_gender_output_accuracy: 0.8505 - val_age_output_accuracy: 0.0400
# Epoch 13/50
# 134/134 [==============================] - 67s 500ms/step - loss: 7.6366 - gender_output_loss: 0.3459 - age_output_loss: 7.2907 - gender_output_accuracy: 0.8427 - age_output_accuracy: 0.0354 - val_loss: 8.1505 - val_gender_output_loss: 0.3537 - val_age_output_loss: 7.7969 - val_gender_output_accuracy: 0.8337 - val_age_output_accuracy: 0.0358
# Epoch 14/50
# 134/134 [==============================] - 69s 513ms/step - loss: 7.5428 - gender_output_loss: 0.3356 - age_output_loss: 7.2073 - gender_output_accuracy: 0.8497 - age_output_accuracy: 0.0342 - val_loss: 8.1619 - val_gender_output_loss: 0.3860 - val_age_output_loss: 7.7759 - val_gender_output_accuracy: 0.8232 - val_age_output_accuracy: 0.0484
# Epoch 15/50
# 134/134 [==============================] - 69s 511ms/step - loss: 7.3080 - gender_output_loss: 0.3084 - age_output_loss: 6.9997 - gender_output_accuracy: 0.8572 - age_output_accuracy: 0.0377 - val_loss: 8.4570 - val_gender_output_loss: 0.3308 - val_age_output_loss: 8.1262 - val_gender_output_accuracy: 0.8421 - val_age_output_accuracy: 0.0379
# Epoch 16/50
# 134/134 [==============================] - 69s 512ms/step - loss: 7.1186 - gender_output_loss: 0.3057 - age_output_loss: 6.8129 - gender_output_accuracy: 0.8678 - age_output_accuracy: 0.0349 - val_loss: 8.1922 - val_gender_output_loss: 0.3263 - val_age_output_loss: 7.8659 - val_gender_output_accuracy: 0.8505 - val_age_output_accuracy: 0.0484
# Epoch 17/50
# 134/134 [==============================] - 90s 676ms/step - loss: 6.8377 - gender_output_loss: 0.2874 - age_output_loss: 6.5503 - gender_output_accuracy: 0.8662 - age_output_accuracy: 0.0345 - val_loss: 8.0891 - val_gender_output_loss: 0.3352 - val_age_output_loss: 7.7539 - val_gender_output_accuracy: 0.8526 - val_age_output_accuracy: 0.0442
# Epoch 18/50
# 134/134 [==============================] - 72s 535ms/step - loss: 6.6208 - gender_output_loss: 0.2932 - age_output_loss: 6.3276 - gender_output_accuracy: 0.8617 - age_output_accuracy: 0.0368 - val_loss: 9.0722 - val_gender_output_loss: 0.3304 - val_age_output_loss: 8.7418 - val_gender_output_accuracy: 0.8400 - val_age_output_accuracy: 0.0316
# Epoch 19/50
# 134/134 [==============================] - 70s 525ms/step - loss: 6.5101 - gender_output_loss: 0.2879 - age_output_loss: 6.2221 - gender_output_accuracy: 0.8751 - age_output_accuracy: 0.0368 - val_loss: 7.7745 - val_gender_output_loss: 0.3258 - val_age_output_loss: 7.4487 - val_gender_output_accuracy: 0.8442 - val_age_output_accuracy: 0.0505
# Epoch 20/50
# 134/134 [==============================] - 68s 507ms/step - loss: 6.1716 - gender_output_loss: 0.2782 - age_output_loss: 5.8934 - gender_output_accuracy: 0.8762 - age_output_accuracy: 0.0373 - val_loss: 8.0589 - val_gender_output_loss: 0.3174 - val_age_output_loss: 7.7414 - val_gender_output_accuracy: 0.8463 - val_age_output_accuracy: 0.0484
# Epoch 21/50
# 134/134 [==============================] - 67s 500ms/step - loss: 6.0496 - gender_output_loss: 0.2699 - age_output_loss: 5.7798 - gender_output_accuracy: 0.8774 - age_output_accuracy: 0.0377 - val_loss: 8.5965 - val_gender_output_loss: 0.3467 - val_age_output_loss: 8.2498 - val_gender_output_accuracy: 0.8337 - val_age_output_accuracy: 0.0484
# Epoch 22/50
# 134/134 [==============================] - 67s 498ms/step - loss: 5.8767 - gender_output_loss: 0.2477 - age_output_loss: 5.6290 - gender_output_accuracy: 0.8870 - age_output_accuracy: 0.0394 - val_loss: 7.9547 - val_gender_output_loss: 0.3241 - val_age_output_loss: 7.6305 - val_gender_output_accuracy: 0.8421 - val_age_output_accuracy: 0.0589
# Epoch 23/50
# 134/134 [==============================] - 5605s 42s/step - loss: 6.0542 - gender_output_loss: 0.2516 - age_output_loss: 5.8026 - gender_output_accuracy: 0.8856 - age_output_accuracy: 0.0389 - val_loss: 7.6255 - val_gender_output_loss: 0.3112 - val_age_output_loss: 7.3144 - val_gender_output_accuracy: 0.8589 - val_age_output_accuracy: 0.0505
# Epoch 24/50
# 134/134 [==============================] - 112s 838ms/step - loss: 5.5992 - gender_output_loss: 0.2361 - age_output_loss: 5.3631 - gender_output_accuracy: 0.8931 - age_output_accuracy: 0.0398 - val_loss: 7.9530 - val_gender_output_loss: 0.3105 - val_age_output_loss: 7.6425 - val_gender_output_accuracy: 0.8589 - val_age_output_accuracy: 0.0505
# Epoch 25/50
# 134/134 [==============================] - 113s 845ms/step - loss: 5.4908 - gender_output_loss: 0.2341 - age_output_loss: 5.2568 - gender_output_accuracy: 0.8959 - age_output_accuracy: 0.0375 - val_loss: 8.5206 - val_gender_output_loss: 0.3298 - val_age_output_loss: 8.1909 - val_gender_output_accuracy: 0.8526 - val_age_output_accuracy: 0.0589
# Epoch 26/50
# 134/134 [==============================] - 113s 841ms/step - loss: 5.4717 - gender_output_loss: 0.2356 - age_output_loss: 5.2361 - gender_output_accuracy: 0.8919 - age_output_accuracy: 0.0394 - val_loss: 7.7775 - val_gender_output_loss: 0.3161 - val_age_output_loss: 7.4615 - val_gender_output_accuracy: 0.8568 - val_age_output_accuracy: 0.0547
# Epoch 27/50
# 134/134 [==============================] - 113s 845ms/step - loss: 5.1837 - gender_output_loss: 0.2189 - age_output_loss: 4.9649 - gender_output_accuracy: 0.9025 - age_output_accuracy: 0.0403 - val_loss: 7.7115 - val_gender_output_loss: 0.3134 - val_age_output_loss: 7.3982 - val_gender_output_accuracy: 0.8632 - val_age_output_accuracy: 0.0547
# Epoch 28/50
# 134/134 [==============================] - 112s 837ms/step - loss: 5.3038 - gender_output_loss: 0.2164 - age_output_loss: 5.0873 - gender_output_accuracy: 0.8994 - age_output_accuracy: 0.0434 - val_loss: 7.6672 - val_gender_output_loss: 0.3215 - val_age_output_loss: 7.3457 - val_gender_output_accuracy: 0.8505 - val_age_output_accuracy: 0.0484
# Epoch 29/50
# 134/134 [==============================] - 113s 845ms/step - loss: 5.0689 - gender_output_loss: 0.2062 - age_output_loss: 4.8627 - gender_output_accuracy: 0.9088 - age_output_accuracy: 0.0434 - val_loss: 7.9501 - val_gender_output_loss: 0.3322 - val_age_output_loss: 7.6179 - val_gender_output_accuracy: 0.8611 - val_age_output_accuracy: 0.0547
# Epoch 30/50
# 134/134 [==============================] - 113s 846ms/step - loss: 5.0539 - gender_output_loss: 0.2084 - age_output_loss: 4.8455 - gender_output_accuracy: 0.9039 - age_output_accuracy: 0.0436 - val_loss: 8.0090 - val_gender_output_loss: 0.3211 - val_age_output_loss: 7.6879 - val_gender_output_accuracy: 0.8568 - val_age_output_accuracy: 0.0568
# Epoch 31/50
# 134/134 [==============================] - 113s 845ms/step - loss: 4.9265 - gender_output_loss: 0.2058 - age_output_loss: 4.7208 - gender_output_accuracy: 0.9053 - age_output_accuracy: 0.0401 - val_loss: 8.2527 - val_gender_output_loss: 0.3323 - val_age_output_loss: 7.9204 - val_gender_output_accuracy: 0.8589 - val_age_output_accuracy: 0.0463
# Epoch 32/50
# 134/134 [==============================] - 114s 848ms/step - loss: 4.8423 - gender_output_loss: 0.1915 - age_output_loss: 4.6507 - gender_output_accuracy: 0.9154 - age_output_accuracy: 0.0403 - val_loss: 7.6691 - val_gender_output_loss: 0.3307 - val_age_output_loss: 7.3384 - val_gender_output_accuracy: 0.8632 - val_age_output_accuracy: 0.0526
# Epoch 33/50
# 134/134 [==============================] - 114s 848ms/step - loss: 4.7853 - gender_output_loss: 0.1911 - age_output_loss: 4.5942 - gender_output_accuracy: 0.9189 - age_output_accuracy: 0.0427 - val_loss: 7.6563 - val_gender_output_loss: 0.3465 - val_age_output_loss: 7.3098 - val_gender_output_accuracy: 0.8568 - val_age_output_accuracy: 0.0547
# Epoch 34/50
# 134/134 [==============================] - 113s 841ms/step - loss: 4.6669 - gender_output_loss: 0.1854 - age_output_loss: 4.4816 - gender_output_accuracy: 0.9194 - age_output_accuracy: 0.0431 - val_loss: 7.6652 - val_gender_output_loss: 0.3668 - val_age_output_loss: 7.2984 - val_gender_output_accuracy: 0.8421 - val_age_output_accuracy: 0.0505
# Epoch 35/50
# 134/134 [==============================] - 113s 846ms/step - loss: 4.6085 - gender_output_loss: 0.1749 - age_output_loss: 4.4336 - gender_output_accuracy: 0.9217 - age_output_accuracy: 0.0448 - val_loss: 8.1150 - val_gender_output_loss: 0.3567 - val_age_output_loss: 7.7583 - val_gender_output_accuracy: 0.8611 - val_age_output_accuracy: 0.0568
# Epoch 36/50
# 134/134 [==============================] - 112s 839ms/step - loss: 4.5746 - gender_output_loss: 0.1763 - age_output_loss: 4.3982 - gender_output_accuracy: 0.9191 - age_output_accuracy: 0.0410 - val_loss: 7.7999 - val_gender_output_loss: 0.3528 - val_age_output_loss: 7.4471 - val_gender_output_accuracy: 0.8526 - val_age_output_accuracy: 0.0526
# Epoch 37/50
# 134/134 [==============================] - 113s 843ms/step - loss: 4.4396 - gender_output_loss: 0.1687 - age_output_loss: 4.2710 - gender_output_accuracy: 0.9245 - age_output_accuracy: 0.0427 - val_loss: 7.7362 - val_gender_output_loss: 0.3581 - val_age_output_loss: 7.3781 - val_gender_output_accuracy: 0.8632 - val_age_output_accuracy: 0.0547
# Epoch 38/50
# 134/134 [==============================] - 113s 843ms/step - loss: 4.5254 - gender_output_loss: 0.1688 - age_output_loss: 4.3567 - gender_output_accuracy: 0.9231 - age_output_accuracy: 0.0429 - val_loss: 7.7790 - val_gender_output_loss: 0.3613 - val_age_output_loss: 7.4177 - val_gender_output_accuracy: 0.8695 - val_age_output_accuracy: 0.0484
# Epoch 39/50
# 134/134 [==============================] - 113s 840ms/step - loss: 4.3890 - gender_output_loss: 0.1547 - age_output_loss: 4.2344 - gender_output_accuracy: 0.9287 - age_output_accuracy: 0.0455 - val_loss: 8.3602 - val_gender_output_loss: 0.3797 - val_age_output_loss: 7.9805 - val_gender_output_accuracy: 0.8505 - val_age_output_accuracy: 0.0589
# Epoch 40/50
# 134/134 [==============================] - 113s 845ms/step - loss: 4.3551 - gender_output_loss: 0.1604 - age_output_loss: 4.1947 - gender_output_accuracy: 0.9255 - age_output_accuracy: 0.0424 - val_loss: 7.7337 - val_gender_output_loss: 0.3675 - val_age_output_loss: 7.3662 - val_gender_output_accuracy: 0.8526 - val_age_output_accuracy: 0.0526
# Epoch 41/50
# 134/134 [==============================] - 113s 845ms/step - loss: 4.2170 - gender_output_loss: 0.1617 - age_output_loss: 4.0553 - gender_output_accuracy: 0.9346 - age_output_accuracy: 0.0443 - val_loss: 7.6894 - val_gender_output_loss: 0.3664 - val_age_output_loss: 7.3230 - val_gender_output_accuracy: 0.8758 - val_age_output_accuracy: 0.0484
# Epoch 42/50
# 134/134 [==============================] - 113s 845ms/step - loss: 4.2483 - gender_output_loss: 0.1685 - age_output_loss: 4.0798 - gender_output_accuracy: 0.9280 - age_output_accuracy: 0.0443 - val_loss: 7.9754 - val_gender_output_loss: 0.3807 - val_age_output_loss: 7.5947 - val_gender_output_accuracy: 0.8716 - val_age_output_accuracy: 0.0611
# Epoch 43/50
# 134/134 [==============================] - 113s 845ms/step - loss: 4.2171 - gender_output_loss: 0.1540 - age_output_loss: 4.0631 - gender_output_accuracy: 0.9280 - age_output_accuracy: 0.0457 - val_loss: 7.8907 - val_gender_output_loss: 0.4104 - val_age_output_loss: 7.4803 - val_gender_output_accuracy: 0.8463 - val_age_output_accuracy: 0.0568
# Epoch 44/50
# 134/134 [==============================] - 113s 846ms/step - loss: 4.1588 - gender_output_loss: 0.1582 - age_output_loss: 4.0006 - gender_output_accuracy: 0.9339 - age_output_accuracy: 0.0431 - val_loss: 7.8369 - val_gender_output_loss: 0.3716 - val_age_output_loss: 7.4654 - val_gender_output_accuracy: 0.8611 - val_age_output_accuracy: 0.0505
# Epoch 45/50
# 134/134 [==============================] - 113s 842ms/step - loss: 4.1467 - gender_output_loss: 0.1456 - age_output_loss: 4.0012 - gender_output_accuracy: 0.9325 - age_output_accuracy: 0.0443 - val_loss: 7.7840 - val_gender_output_loss: 0.3954 - val_age_output_loss: 7.3886 - val_gender_output_accuracy: 0.8568 - val_age_output_accuracy: 0.0547
# Epoch 46/50
# 134/134 [==============================] - 113s 846ms/step - loss: 4.2241 - gender_output_loss: 0.1457 - age_output_loss: 4.0784 - gender_output_accuracy: 0.9353 - age_output_accuracy: 0.0448 - val_loss: 7.9419 - val_gender_output_loss: 0.4115 - val_age_output_loss: 7.5303 - val_gender_output_accuracy: 0.8632 - val_age_output_accuracy: 0.0547
# Epoch 47/50
# 134/134 [==============================] - 113s 842ms/step - loss: 4.1814 - gender_output_loss: 0.1483 - age_output_loss: 4.0331 - gender_output_accuracy: 0.9344 - age_output_accuracy: 0.0431 - val_loss: 8.0315 - val_gender_output_loss: 0.3864 - val_age_output_loss: 7.6451 - val_gender_output_accuracy: 0.8653 - val_age_output_accuracy: 0.0589
# Epoch 48/50
# 134/134 [==============================] - 113s 842ms/step - loss: 4.1488 - gender_output_loss: 0.1454 - age_output_loss: 4.0034 - gender_output_accuracy: 0.9339 - age_output_accuracy: 0.0445 - val_loss: 7.9000 - val_gender_output_loss: 0.3866 - val_age_output_loss: 7.5134 - val_gender_output_accuracy: 0.8484 - val_age_output_accuracy: 0.0568
# Epoch 49/50
# 134/134 [==============================] - 113s 844ms/step - loss: 3.9806 - gender_output_loss: 0.1308 - age_output_loss: 3.8498 - gender_output_accuracy: 0.9447 - age_output_accuracy: 0.0429 - val_loss: 7.8606 - val_gender_output_loss: 0.4056 - val_age_output_loss: 7.4550 - val_gender_output_accuracy: 0.8653 - val_age_output_accuracy: 0.0589
# Epoch 50/50
# 134/134 [==============================] - 113s 843ms/step - loss: 4.1252 - gender_output_loss: 0.1350 - age_output_loss: 3.9901 - gender_output_accuracy: 0.9395 - age_output_accuracy: 0.0455 - val_loss: 7.8128 - val_gender_output_loss: 0.4108 - val_age_output_loss: 7.4019 - val_gender_output_accuracy: 0.8526 - val_age_output_accuracy: 0.0611

# %%
# Plot loss and accuracy for gender
plt.plot(model_history.history['gender_output_loss'])
plt.plot(model_history.history['val_gender_output_loss'])
plt.title('Gender Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
plt.plot(model_history.history['gender_output_accuracy'])
plt.plot(model_history.history['val_gender_output_accuracy'])
plt.title('Gender Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
model.save("model.h5")
# Out:
# C:\Users\THUNDER REDDY\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
